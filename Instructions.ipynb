# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio
# **ADAM BAOUID**
#
# *I am interested in data science because i want to know my customers more closely so that i could serve them better and also to make great decisions.*

# %% [markdown]
# ### The code will output the sum of two numbers!

# %%
a = 2
b = 4
print(a + b)
# Out:
# 6

# %% [markdown]
# 1. Car
# 2. Bike
# 3. Motorcycle
#
# 	---
#
# # Hello > ## Hi
